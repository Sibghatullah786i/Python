# %%
while True:
        print("*** Currency Converter ***")


        #Exchnage Rates Assigned
        usd = 1.0
        eur = 0.95
        gbp = 0.79
        yen = 153.86
        cny = 7.28
        inr = 84.81

        bdt = 119.27
        sar = 3.76
        aed = 3.67
        kwd = 0.31
        Try = 34.95
        pkr = 277.56




        one = "1-USD (US Dollar)\n"
        two = "2-EUR (Euro)\n"
        three = "3-GBP (British Pound)\n"
        four = "4-YEN (Japanese Yen)\n"
        five = "5-CNY (Chinese Yuan)\n"
        six = "6-INR (Indian Rupee)\n"
        seven = "7-BDT (Bangladeshi Taka)\n"
        eight = "8-SAR (Saudi Riyal)\n"
        nine = "9-AED (United Arab Emirates Dirham)\n"
        ten = "10-KWD (Kuwaiti Dinar)\n"
        eleven = "11-TRY (Turkish Lira)\n"
        twelve = "12-PKR (Pakistani Rupee)\n"



        print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)



        #ask user which currency wanna exchange
        currency = input("Which Currency do you want to convert : ")

        #USD to any currency  
        if currency == "1":
            usd_ammount = int(input("Enter Ammount of USD :"))  
            if usd_ammount > 0 :

                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_usd = usd_ammount * usd 
                    print("The Amount of USD (US Dollar) is :",cal_usd)
                
                elif cur_which == 2:
                    cal_eur = usd_ammount * eur / usd
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = usd_ammount * gbp / usd
                    print("The Amount of GBP is (British Pound) :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = usd_ammount * yen / usd
                    print("The Amount of YEN is (Japanese Yen) :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = usd_ammount * cny / usd
                    print("The Amount of CNY is (Chinese Yuan) :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = usd_ammount * inr / usd
                    print("The Amount of INR is (Indian Rupee) :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = usd_ammount * bdt / usd
                    print("The Amount of BDT is (Bangladeshi Taka) :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = usd_ammount * sar / usd
                    print("The Amount of SAR is (Saudi Riyal) :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = usd_ammount * aed / usd
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = usd_ammount * kwd / usd
                    print("The Amount of KWD is (Kuwaiti Dinar) :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = usd_ammount * Try / usd
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = usd_ammount * pkr / usd
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of USD ")
        


        #Euro to any Currency

        elif currency == "2":
            euro_ammount = int(input("Enter Ammount of EURO :"))
            if euro_ammount > 0 :
              
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_euro = euro_ammount * usd / eur
                    print("The Amount of USD (US Dollar) is :",cal_euro)
                
                elif cur_which == 2:
                    cal_eur = euro_ammount * eur / eur
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = euro_ammount * gbp /eur
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = euro_ammount * yen /eur
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = euro_ammount * cny /eur
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = euro_ammount * inr /eur
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = euro_ammount * bdt /eur
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = euro_ammount * sar /eur
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = euro_ammount * aed /eur
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = euro_ammount * kwd /eur
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = euro_ammount * Try /eur
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = euro_ammount * pkr /eur
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of EURO ")

        #GBP (British Pound) to any currency 
        elif currency == "3":
            gbp_ammount = int(input("Enter Ammount of GBP (British Pound) :"))
            if gbp_ammount > 0 :
                
                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_gbp = gbp_ammount * usd /gbp
                    print("The Amount of USD (US Dollar) is :",cal_gbp)
                
                elif cur_which == 2:
                    cal_eur = gbp_ammount * eur /gbp
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = gbp_ammount * gbp /gbp
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = gbp_ammount * yen /gbp
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = gbp_ammount * cny /gbp
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = gbp_ammount * inr /gbp
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = gbp_ammount * bdt /gbp
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = gbp_ammount * sar /gbp
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = gbp_ammount * aed /gbp
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = gbp_ammount * kwd /gbp
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = gbp_ammount * Try /gbp
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = gbp_ammount * pkr /gbp
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of GBP (British Pound) ")
                
        #YEN (Japanese Yen) to any currency 
        elif currency == "4":
            yen_ammount = int(input("Enter Ammount of YEN (Japanese Yen) :"))
            if yen_ammount > 0 :
                
                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_yen = yen_ammount * usd /yen
                    print("The Amount of USD (US Dollar) is :",cal_yen)
                
                elif cur_which == 2:
                    cal_eur = yen_ammount * eur /yen
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = yen_ammount * gbp /yen
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = yen_ammount * yen /yenS
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = yen_ammount * cny /yen
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = yen_ammount * inr /yen
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = yen_ammount * bdt /yen
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = yen_ammount * sar /yen
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = yen_ammount * aed /yen
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = yen_ammount * kwd /yen
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = yen_ammount * Try /yen
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = yen_ammount * pkr /yen
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of YEN (Japanese Yen) ")

        #CNY (Chinese Yuan) to any currency

        elif currency == "5":
            cny_ammount = int(input("Enter Ammount of CNY (Chinese Yuan) :"))
            if cny_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_cny = cny_ammount * usd / cny
                    print("The Amount of USD (US Dollar) is :",cal_cny)
                
                elif cur_which == 2:
                    cal_eur = cny_ammount * eur / cny
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = cny_ammount * gbp / cny
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = cny_ammount * yen / cny
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = cny_ammount * cny / cny
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = cny_ammount * inr / cny
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = cny_ammount * bdt / cny
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = cny_ammount * sar / cny
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = cny_ammount * aed / cny
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = cny_ammount * kwd / cny
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = cny_ammount * Try / cny
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = cny_ammount * pkr / cny
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of YEN (Japanese Yen) ")

        #INR (Indian Rupee) to any currency

        elif currency == "6":
            inr_ammount = int(input("Enter Ammount of INR (Indian Rupee) :"))
            if inr_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_inr = inr_ammount * usd / inr
                    print("The Amount of USD (US Dollar) is :",cal_inr)
                
                elif cur_which == 2:
                    cal_eur = inr_ammount * eur / inr
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = inr_ammount * gbp / inr
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = inr_ammount * yen / inr
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = inr_ammount * cny / inr
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = inr_ammount * inr / inr
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = inr_ammount * bdt / inr
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = inr_ammount * sar / inr
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = inr_ammount * aed / inr
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = inr_ammount * kwd / inr
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = inr_ammount * Try / inr
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = inr_ammount * pkr / inr
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of INR (Indian Rupee) ")

        #BDT (Bangladeshi Taka) to any currency

        elif currency == "7":
            bdt_ammount = int(input("Enter Ammount of BDT (Bangladeshi Taka) :"))
            if bdt_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_bdt = bdt_ammount * usd / bdt
                    print("The Amount of USD (US Dollar) is :",cal_bdt)
                
                elif cur_which == 2:
                    cal_eur = bdt_ammount * eur / bdt
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = bdt_ammount * gbp / bdt
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = bdt_ammount * yen / bdt
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = bdt_ammount * cny / bdt
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = bdt_ammount * inr / bdt
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = bdt_ammount * bdt / bdt
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = bdt_ammount * sar / bdt
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = bdt_ammount * aed / bdt
                    print("The Amount of AED is (United Arab Emirates Dirham) :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = bdt_ammount * kwd / bdt
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = bdt_ammount * Try / bdt
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = bdt_ammount * pkr / bdt
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of BDT (Bangladeshi Taka) ")

        #SAR (Saudi Riyal) to any currency

        elif currency == "8":
            sar_ammount = int(input("Enter Ammount of SAR (Saudi Riyal) :"))
            if sar_ammount > 0 :
                
                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_sar = sar_ammount * usd / sar
                    print("The Amount of USD (US Dollar) is :",cal_sar)
                
                elif cur_which == 2:
                    cal_eur = sar_ammount * eur / sar
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = sar_ammount * gbp / sar
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = sar_ammount * yen / sar
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = sar_ammount * cny / sar
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = sar_ammount * inr / sar
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = sar_ammount * bdt / sar
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = sar_ammount * sar / sar
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = sar_ammount * aed / sar
                    print("The Amount of AED (United Arab Emirates Dirham) is :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = sar_ammount * kwd / sar
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                
                    cal_Try = sar_ammount * Try / sar
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = sar_ammount * pkr / sar
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of SAR (Saudi Riyal)) ")

        # AED (United Arab Emirates Dirham) to any currency

        elif currency == "9":
            aed_ammount = int(input("Enter Ammount of AED (United Arab Emirates Dirham) :"))
            if aed_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_aed = aed_ammount * usd / aed
                    print("The Amount of USD (US Dollar) is :",cal_aed)
                
                elif cur_which == 2:
                    cal_eur = aed_ammount * eur / aed
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = aed_ammount * gbp / aed
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = aed_ammount * yen / aed
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = aed_ammount * cny / aed
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = aed_ammount * inr / aed
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = aed_ammount * bdt / aed
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = aed_ammount * sar / aed
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = aed_ammount * aed / aed
                    print("The Amount of AED (United Arab Emirates Dirham) is :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = aed_ammount * kwd / aed
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = aed_ammount * Try / aed
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = aed_ammount * pkr / aed
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of AED (United Arab Emirates Dirham) ")

        #KWD (Kuwaiti Dinar) to any currency

        elif currency == "10":
            kwd_ammount = int(input("Enter Ammount of KWD (Kuwaiti Dinar) :"))
            if kwd_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_kwd = kwd_ammount * usd / kwd
                    print("The Amount of USD (US Dollar) is :",cal_kwd)
                
                elif cur_which == 2:
                    cal_eur = kwd_ammount * eur / kwd
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = kwd_ammount * gbp / kwd
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = kwd_ammount * yen / kwd
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = kwd_ammount * cny / kwd
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = kwd_ammount * inr / kwd
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = kwd_ammount * bdt / kwd
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = kwd_ammount * sar / kwd
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = kwd_ammount * aed / kwd
                    print("The Amount of AED (United Arab Emirates Dirham) is :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = kwd_ammount * kwd / kwd
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = kwd_ammount * Try / kwd
                    print("The Amount of TRY (Turkish Lira) is :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = kwd_ammount * pkr / kwd
                    print("The Amount of PKR (Pakistani Rupee) is :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of KWD (Kuwaiti Dinar) ")

        #TRY (Turkish Lira) to any currency

        elif currency == "11":
            try_ammount = int(input("Enter Ammount of TRY (Turkish Lira) :"))
            if try_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_try = try_ammount * usd / Try
                    print("The Amount of USD (US Dollar) is :",cal_try)
                
                elif cur_which == 2:
                    cal_eur = try_ammount * eur / Try
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = try_ammount * gbp / Try
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = try_ammount * yen / Try
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = try_ammount * cny / Try
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = try_ammount * inr / Try
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = try_ammount * bdt / Try
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = try_ammount * sar / Try
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = try_ammount * aed / Try
                    print("The Amount of AED (United Arab Emirates Dirham) is :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = try_ammount * kwd / Try
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = try_ammount * Try / Try
                    print("The Amount of TRY (Turkish Lira) is :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = try_ammount * pkr / Try
                    print("The Amount of PKR (Pakistani Rupee) is :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of TRY (Turkish Lira) ")

        #PKR (Pakistani Rupee) to any currency

        elif currency == "12":
            pkr_ammount = int(input("Enter Ammount of PKR (Pakistani Rupee) :"))
            if pkr_ammount > 0 :
                

                
                print(one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve)
                cur_which = int(input("In which currency do you want to convert :"))
                
                if cur_which == 1:
                    cal_pkr = pkr_ammount * usd / pkr
                    print("The Amount of USD (US Dollar) is :",cal_pkr)
                
                elif cur_which == 2:
                    cal_eur = pkr_ammount * eur / pkr
                    print("The Amount of EUR (Euro) is :",format(cal_eur,'.2f')) 
                elif cur_which == 3:
                    cal_gbp = pkr_ammount * gbp / pkr
                    print("The Amount of GBP (British Pound) is :",format(cal_gbp,'.2f'))
                elif cur_which == 4:
                    cal_yen = pkr_ammount * yen / pkr
                    print("The Amount of YEN (Japanese Yen) is :",format(cal_yen,'.2f'))
                elif cur_which == 5:
                    cal_cny = pkr_ammount * cny / pkr
                    print("The Amount of CNY (Chinese Yuan) is :",format(cal_cny,'.2f'))
                
                elif cur_which == 6:
                    cal_inr = pkr_ammount * inr / pkr
                    print("The Amount of INR (Indian Rupee) is :",format(cal_inr,'.2f'))
                
                elif cur_which == 7:
                    cal_bdt = pkr_ammount * bdt / pkr
                    print("The Amount of BDT (Bangladeshi Taka) is :",format(cal_bdt,'.2f'))
                elif cur_which == 8:
                    cal_sar = pkr_ammount * sar / pkr
                    print("The Amount of SAR (Saudi Riyal) is :",format(cal_sar,'.2f'))
                elif cur_which == 9:
                    cal_aed = pkr_ammount * aed / pkr
                    print("The Amount of AED (United Arab Emirates Dirham) is :",format(cal_aed,'.2f'))
                elif cur_which == 10:
                    cal_kwd = pkr_ammount * kwd / pkr
                    print("The Amount of KWD (Kuwaiti Dinar) is :",format(cal_kwd,'.2f'))
                elif cur_which == 11:
                    cal_Try = pkr_ammount * Try / pkr
                    print("The Amount of TRY is (Turkish Lira) :",format(cal_Try,'.2f'))
                elif cur_which == 12:
                    cal_pkr = pkr_ammount * pkr / pkr
                    print("The Amount of PKR is (Pakistani Rupee) :",format(cal_pkr,'.2f'))
                else:
                    cur_which <= 0 or cur_which > 12
                    print("Choose a valid input")
                    
            else:
                print("Enter Valid Amount of PKR (Pakistani Rupee) ")
            

        user_input = input('Do you want to exit (yes/no): ')
        if user_input == 'Yes' or user_input == 'yes':
            print('exiting the program...')
            break
        else:
            print('Restarting...')
